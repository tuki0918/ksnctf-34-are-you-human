# %%
# %matplotlib inline

import cv2
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.7/site-packages/matplotlib/font_manager.py:232: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
def make_gray_image(path):
    # グレースケールで画像を読み込む.
    gray = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    return gray

# %%
import os

base_path = '/Users/yuta/git/github.com/tuki0918/ksnctf-34-are-you-human/resources/image/'

img = make_gray_image(os.path.join(base_path, '00000000.png'))

# %%
plt.figure(figsize=(30,15))
plt.imshow(img, cmap=plt.get_cmap('gray'))

# %%
img = make_gray_image(os.path.join(base_path, '00000010.png'))

plt.figure(figsize=(30,15))
plt.imshow(img, cmap=plt.get_cmap('gray'))

# %%
img = make_gray_image(os.path.join(base_path, '00000030.png'))

plt.figure(figsize=(30,15))
plt.imshow(img, cmap=plt.get_cmap('gray'))

# %%
#　新しい配列に入力画像の一部を代入
x = 0
y = 0
w = 32
h = 32

dist = img[y: y + h, x: x + w]

plt.figure(figsize=(1,1))
plt.imshow(dist, cmap=plt.get_cmap('gray'))

# %%
#　新しい配列に入力画像の一部を代入
x = 32
y = 0
w = 32
h = 32

dist = img[y: y + h, x: x + w]

plt.figure(figsize=(1,1))
plt.imshow(dist, cmap=plt.get_cmap('gray'))

# %%
#　新しい配列に入力画像の一部を代入
x = 64
y = 0
w = 32
h = 32

dist = img[y: y + h, x: x + w]

plt.figure(figsize=(1,1))
plt.imshow(dist, cmap=plt.get_cmap('gray'))

# %%
#　新しい配列に入力画像の一部を代入
x = 992
y = 0
w = 32
h = 32

dist = img[y: y + h, x: x + w]

plt.figure(figsize=(1,1))
plt.imshow(dist, cmap=plt.get_cmap('gray'))

# %%
cv2.imwrite('dist-31.png', dist)
# Out:
# True
