# %%
import os

base_path = '/Users/yuta/git/github.com/tuki0918/ksnctf-34-are-you-human/resources/dataset-prepare/'

files = os.listdir(base_path)
files_file = [f for f in files if os.path.isfile(os.path.join(base_path, f))]
# print(files_file)   # ['file1', 'file2.txt', 'file3.jpg']
print(len(files_file))
# Out:
# 242272

# %%
import shutil

dataset_path = '/Users/yuta/git/github.com/tuki0918/ksnctf-34-are-you-human/resources/dataset/'

file_path = os.path.join(base_path, '000000a0-27.png')
dist_dir = os.path.join(dataset_path, '1')

shutil.move(file_path, dist_dir)
# Out:
# '/Users/yuta/git/github.com/tuki0918/ksnctf-34-are-you-human/resources/dataset/1/000000a0-27.png'

# %%
# %matplotlib inline

import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
from keras.models import load_model
model = load_model('model-mnist.h5')
model.summary()

def prepare_x(path):
    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    img_rows, img_cols = 28, 28
    re_img = cv2.resize(img, (img_rows, img_cols))
    re_img = re_img.astype('float32')
    re_img /= 255
    x = re_img.reshape(1, 1, img_rows, img_cols)
    return x

def predict_x(path):
    x = prepare_x(path)
    x_proba = model.predict(x)
    x_classes = x_proba.argmax(axis=-1)
    return x_classes[0]
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_20 (Conv2D)           (None, 32, 26, 26)        320
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 64, 24, 24)        18496
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 64, 12, 12)        0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 64, 12, 12)        0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 9216)              0
# _________________________________________________________________
# dense_20 (Dense)             (None, 128)               1179776
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 128)               0
# ...

# %%
for img_path in files_file:
    try:
        file_path = os.path.join(base_path, img_path)
        x = predict_x(file_path)
        dist_dir = os.path.join(dataset_path, str(x))
        shutil.move(file_path, dist_dir)
    except:
        print(img_path)
# Out:
# 00005b60-31.png
# 0000d2b0-19.png
# 000146c0-27.png
# 000151f0-10.png
# 00012cb0-18.png
# 0001c360-30.png
# 0001c9c0-17.png
# 0001b1b0-21.png
# 00002c10-4.png
# 000032f0-28.png
# 00018d60-5.png
# 0000a6f0-14.png
# 0000a9b0-15.png
# 0000a370-32.png
# 000082c0-1.png
# 000066b0-25.png
# 000069f0-24.png
# 00019580-10.png
# 0001b040-1.png
# 00013240-20.png
# 00012510-17.png
# 0000b100-29.png
# 0000ec40-21.png
# 0000dd10-16.png
# 000191d0-15.png
# 00002c00-10.png
# 000186a0-22.png
# 000189e0-23.png
# 00003d50-27.png
# 00005140-18.png
# 00009c90-17.png
# 0001d200-11.png
# 0000bfa0-5.png
# 00011d40-25.png
# 00010c10-12.png
# 00010e70-4.png
# 00005f00-4.png
# 0000f210-13.png
# 00000500-15.png
# 00001250-22.png
# 00014970-1.png
# 0000afb0-17.png
# 00003100-8.png
# 00016270-8.png
# 00019670-9.png
# 000177b0-16.png
# 000178f0-17.png
# 0001a2f0-9.png
# 00011bc0-29.png
# 0000d1a0-9.png
# 00015150-2.png
# 00000220-2.png
# 00017230-30.png
# 0001a0c0-10.png
# 0001b1d0-3.png
# 0000ac30-31.png
# ...

# %%
file_path = os.path.join(base_path, '00008e10-17.png')
x = predict_x(file_path)
dist_dir = os.path.join(dataset_path, str(x))
shutil.move(file_path, dist_dir)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-14-a40f762f9a76> in <module>
#       1 file_path = os.path.join(base_path, '00008e10-17.png')
# ----> 2 x = predict_x(file_path)
#       3 dist_dir = os.path.join(dataset_path, str(x))
#       4 shutil.move(file_path, dist_dir)
#
# <ipython-input-5-d474b00694cf> in predict_x(path)
#      19
#      20 def predict_x(path):
# ---> 21     x = prepare_x(path)
#      22     x_proba = model.predict(x)
#      23     x_classes = x_proba.argmax(axis=-1)
#
# <ipython-input-5-d474b00694cf> in prepare_x(path)
#      12     img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
#      13     img_rows, img_cols = 28, 28
# ---> 14     re_img = cv2.resize(img, (img_rows, img_cols))
#      15     re_img = re_img.astype('float32')
#      16     re_img /= 255
#
# ...
